# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# %%
# Creating the table for January job postings
job_postings_jan = {
    'Job Title': ['Software Engineer', 'Data Scientist', 'UX/UI Designer', 'Product Manager', 'DevOps Engineer'],
    'Company': ['Google', 'Facebook', 'Apple', 'Microsoft', 'Amazon'],
    'Job Posted Date': ['2024-01-03', '2024-01-12', '2024-01-08', '2024-01-20', '2024-01-15']
}

job_postings_jan = pd.DataFrame(data_january)

# Display the January job postings table
print("January Job Postings:")
print(job_postings_jan)
# Out:
# January Job Postings:
#            Job Title    Company Job Posted Date
# 0  Software Engineer     Google      2024-01-03
# 1     Data Scientist   Facebook      2024-01-12
# 2     UX/UI Designer      Apple      2024-01-08
# 3    Product Manager  Microsoft      2024-01-20
# 4    DevOps Engineer     Amazon      2024-01-15

# %%
# Creating the table for February job postings
job_postings_feb = {
    'Job Title': ['Software Engineer', 'Data Analyst', 'UX Designer', 'Product Manager', 'System Architect'],
    'Company': ['Microsoft', 'Amazon', 'Tesla', 'IBM', 'Oracle'],
    'Job Posted Date': ['2024-02-03', '2024-02-12', '2024-02-08', '2024-02-20', '2024-02-15']
}

job_postings_feb = pd.DataFrame(data_february)

# Display the February job postings table
print("\nFebruary Job Postings:")
print(job_postings_feb)
# Out:
# February Job Postings:
#            Job Title    Company Job Posted Date
# 0  Software Engineer  Microsoft      2024-02-03
# 1       Data Analyst     Amazon      2024-02-12
# 2        UX Designer      Tesla      2024-02-08
# 3    Product Manager        IBM      2024-02-20
# 4   System Architect     Oracle      2024-02-15

# %%
job_postings_jan.merge (job_postings_feb, on = 'Job Title', suffixes = ('_jan', '_feb'))
# Out:
#            Job Title Company_jan Job Posted Date_jan Company_feb  \
# 0  Software Engineer      Google          2024-01-03   Microsoft
# 1    Product Manager   Microsoft          2024-01-20         IBM
#
#   Job Posted Date_feb
# 0          2024-02-03
# 1          2024-02-20

# %%
pd.concat([job_postings_jan, job_postings_feb], ignore_index=True)
# Out:
#            Job Title    Company Job Posted Date
# 0  Software Engineer     Google      2024-01-03
# 1     Data Scientist   Facebook      2024-01-12
# 2     UX/UI Designer      Apple      2024-01-08
# 3    Product Manager  Microsoft      2024-01-20
# 4    DevOps Engineer     Amazon      2024-01-15
# 5  Software Engineer  Microsoft      2024-02-03
# 6       Data Analyst     Amazon      2024-02-12
# 7        UX Designer      Tesla      2024-02-08
# 8    Product Manager        IBM      2024-02-20
# 9   System Architect     Oracle      2024-02-15

# %%
# Load the dataset from the CSV file
dataset = load_dataset('csv', data_files=r'C:\Users\sami.laham\Documents\Sam\Data Analysis Training\Luke Barousse\CSV files\data_jobs.csv')

# Convert the dataset to a pandas DataFrame
df = dataset['train'].to_pandas()

# Data Cleaning: Convert the 'job_posted_date' to datetime
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# Show the first few rows of the DataFrame to check the results

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
#dict_months = {
#    'Jan':  df_jan,
#    'Feb':  df_feb,
#    'Mar':  df_mar,
#    'Apr':  df_apr,
#    'May':  df_may,
#    'Jun':  df_jun,
#    'Jul':  df_jul,
#    'Aug':  df_aug,
#    'Sep':  df_sep,
#    'Oct':  df_oct,
#    'Nov':  df_nov,
#    'Dec':  df_dec
# }

months = df['job_posted_month'].unique()
{month: month for month in months}
dict_months = {month: df [df['job_posted_month'] == month] for month in months}
dict_months['Jan']
# Out:
#           job_title_short                                  job_title  \
# 1            Data Analyst                               Data Analyst
# 20         Data Scientist                             Data Scientist
# 39          Data Engineer                              Data Engineer
# 53          Data Engineer                              Data Engineer
# 55         Data Scientist                             Data Scientist
# ...                   ...                                        ...
# 785699  Software Engineer                        Simulation Engineer
# 785700      Data Engineer                       Data Engineer Ssr/Sr
# 785703       Data Analyst    Data Analyst - CRYPTOGRAPHY - Full-time
# 785704   Business Analyst                           Business Analyst
# 785705       Data Analyst  Expert Business Data Analyst - Now Hiring
#
#                                  job_location             job_via  \
# 1                Guadalajara, Jalisco, Mexico    via BeBee México
# ...

# %%
months = df['job_posted_month'].unique()

dict_months = {month: df [df['job_posted_month'] == month] for month in months}
dict_months['Jan']
# Out:
#           job_title_short                                  job_title  \
# 1            Data Analyst                               Data Analyst
# 20         Data Scientist                             Data Scientist
# 39          Data Engineer                              Data Engineer
# 53          Data Engineer                              Data Engineer
# 55         Data Scientist                             Data Scientist
# ...                   ...                                        ...
# 785699  Software Engineer                        Simulation Engineer
# 785700      Data Engineer                       Data Engineer Ssr/Sr
# 785703       Data Analyst    Data Analyst - CRYPTOGRAPHY - Full-time
# 785704   Business Analyst                           Business Analyst
# 785705       Data Analyst  Expert Business Data Analyst - Now Hiring
#
#                                  job_location             job_via  \
# 1                Guadalajara, Jalisco, Mexico    via BeBee México
# ...

# %%
df_Q1 = pd.concat ([dict_months['Jan'], dict_months['Feb'], dict_months ['Mar']], ignore_index = True)
df_Q1
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
# ...

# %%
df_Q1 ['job_posted_month'].value_counts().plot (kind = 'bar')
plt.yticks (rotation = 45)
plt.xticks(rotation = 45)
plt.ylim(0, 100000)
plt.show()

# %%
df_Q1.head().to_clipboard(sep=",")

# %%
df_Q1.to_csv(r'C:\Users\sami.laham\Documents\Sam\Data Analysis Training\Luke Barousse\CSV files\Quarter1.csv')

# %%
pd.read_csv(r'C:\Users\sami.laham\Documents\Sam\Data Analysis Training\Luke Barousse\CSV files\Quarter1.csv',index_col=0)
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
# ...

# %%
df_Q1.to_excel(r'C:\Users\sami.laham\Documents\Sam\Data Analysis Training\Luke Barousse\CSV files\Quarter1.xlsx')
