# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# %%
# Loading Data
dataset = load_dataset('csv', data_files=r'C:\Users\sami.laham\Documents\Sam\Data Analysis Training\Luke Barousse\CSV files\data_jobs.csv')
df = dataset ['train'].to_pandas()

# Data Cleaning

df ['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
print (dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['job_title_short', 'job_title', 'job_location', 'job_via', 'job_schedule_type', 'job_work_from_home', 'search_location', 'job_posted_date', 'job_no_degree_mention', 'job_health_insurance', 'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg', 'company_name', 'job_skills', 'job_type_skills'],
#         num_rows: 785741
#     })
# })

# %%
df_Spain = df[df['job_country'] == 'Spain']
df_Spain
# Out:
#               job_title_short  \
# 115            Data Scientist
# 124            Data Scientist
# 226             Data Engineer
# 258             Data Engineer
# 264      Senior Data Engineer
# ...                       ...
# 785279           Data Analyst
# 785284      Software Engineer
# 785320  Senior Data Scientist
# 785336          Data Engineer
# 785620          Data Engineer
#
#                                                 job_title      job_location  \
# 115                               Azure Big Data Engineer     Madrid, Spain
# 124                                        DATA SCIENTIST     Madrid, Spain
# 226                              Data Engineer con Python             Spain
# 258                                         Data Engineer  Barcelona, Spain
# 264                                   Senior Engineer- MS     Madrid, Spain
# ...                                                   ...               ...
# ...

# %%
df_Spain['job_posted_month'] = df_Spain ['job_posted_date'].dt.strftime('%B')
df_Spain
# Out:
# C:\Users\sami.laham\AppData\Local\Temp\ipykernel_22712\1778188345.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Spain['job_posted_month'] = df_Spain ['job_posted_date'].dt.strftime('%B')
#               job_title_short  \
# 115            Data Scientist
# 124            Data Scientist
# 226             Data Engineer
# 258             Data Engineer
# 264      Senior Data Engineer
# ...                       ...
# 785279           Data Analyst
# 785284      Software Engineer
# 785320  Senior Data Scientist
# 785336          Data Engineer
# 785620          Data Engineer
#
#                                                 job_title      job_location  \
# 115                               Azure Big Data Engineer     Madrid, Spain
# ...

# %%
df_Spain
# Out:
#               job_title_short  \
# 115            Data Scientist
# 124            Data Scientist
# 226             Data Engineer
# 258             Data Engineer
# 264      Senior Data Engineer
# ...                       ...
# 785279           Data Analyst
# 785284      Software Engineer
# 785320  Senior Data Scientist
# 785336          Data Engineer
# 785620          Data Engineer
#
#                                                 job_title      job_location  \
# 115                               Azure Big Data Engineer     Madrid, Spain
# 124                                        DATA SCIENTIST     Madrid, Spain
# 226                              Data Engineer con Python             Spain
# 258                                         Data Engineer  Barcelona, Spain
# 264                                   Senior Engineer- MS     Madrid, Spain
# ...                                                   ...               ...
# ...

# %%
df_Spain.pivot_table(index= 'job_posted_month', columns = 'job_title_short', aggfunc = 'size')
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# April                           45              24           361
# August                         129              47           541
# December                       221              93           531
# February                       127              31           399
# January                        187              65           560
# July                            74              22           382
# June                            77              26           344
# March                           74              23           363
# May                             49              11           395
# November                       184              88           440
# October                        211              76           458
# September                      127              61           403
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_Spain_pivot = df_Spain.pivot_table(index= 'job_posted_month', columns = 'job_title_short', aggfunc = 'size')
df_Spain_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# April                           45              24           361
# August                         129              47           541
# December                       221              93           531
# February                       127              31           399
# January                        187              65           560
# July                            74              22           382
# June                            77              26           344
# March                           74              23           363
# May                             49              11           395
# November                       184              88           440
# October                        211              76           458
# September                      127              61           403
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_Spain_pivot.reset_index(inplace=True)

# %%
df_Spain_pivot ['month_num'] = pd.to_datetime (df_Spain_pivot ['job_posted_month'], format = '%B').dt.month
df_Spain_pivot ['month_num']
# Out:
# 0      4
# 1      8
# 2     12
# 3      2
# 4      1
# 5      7
# 6      6
# 7      3
# 8      5
# 9     11
# 10    10
# 11     9
# Name: month_num, dtype: int32

# %%
df_Spain_pivot
# Out:
# job_title_short job_posted_month  Business Analyst  Cloud Engineer  \
# 0                          April                45              24
# 1                         August               129              47
# 2                       December               221              93
# 3                       February               127              31
# 4                        January               187              65
# 5                           July                74              22
# 6                           June                77              26
# 7                          March                74              23
# 8                            May                49              11
# 9                       November               184              88
# 10                       October               211              76
# 11                     September               127              61
#
# job_title_short  Data Analyst  Data Engineer  Data Scientist  \
# ...

# %%
df_Spain_pivot.sort_values('month_num', inplace = True)

# %%
df_Spain_pivot.set_index('job_posted_month', inplace=True)

# %%
df_Spain_pivot.drop(columns = 'month_num', inplace = True)

# %%
Top_3 = df_Spain ['job_title_short'].value_counts().head(3)
Top_3= Top_3.index.tolist()

# %%
---------------------------------------------------------------------------
AttributeError                            Traceback (most recent call last)
Cell In[27], line 4
      2 plt.title ('Monthly Job Postings for Top Tech Jobs in Spain')
      3 plt.xlabel ('2023')
----> 4 plt.ylabel ('Job Count', rotate = 45)
      5 plt.ylim(0, 20000)
      6 plt.show()

File c:\Users\sami.laham\AppData\Local\anaconda3\Lib\site-packages\matplotlib\pyplot.py:4374, in ylabel(ylabel, fontdict, labelpad, loc, **kwargs)
   4365 @_copy_docstring_and_deprecators(Axes.set_ylabel)
   4366 def ylabel(
   4367     ylabel: str,
   (...)
   4372     **kwargs,
   4373 ) -> Text:
-> 4374     return gca().set_ylabel(
   4375         ylabel, fontdict=fontdict, labelpad=labelpad, loc=loc, **kwargs
   4376     )

File c:\Users\sami.laham\AppData\Local\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:3809, in _AxesBase.set_ylabel(self, ylabel, fontdict, labelpad, loc, **kwargs)
   3802     y, ha = {
   3803         'bottom': (0, 'left'),
   3804         'center': (0.5, 'center'),
   3805         'top': (1, 'right')
...
   1191                     errfmt.format(cls=type(self), prop_name=k))
   1192             ret.append(func(v))
   1193 if ret:

AttributeError: 'Text' object has no property 'rotate'
Output is truncated. View as a scrollable element or open in a text editor. Adjust cell output settings...
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
df_Spain_pivot.to_csv(r'C:\Users\sami.laham\Documents\Sam\Data Analysis Training\Luke Barousse\CSV files\df_Spain_pivot.csv', index=True)

# Print a confirmation message
print("File updated and saved as 'C:\\Users\\sami.laham\\Documents\\Sam\\Data Analysis Training\\Luke Barousse\\CSV files\\df_Spain_pivot.csv'")
# Out:
# File updated and saved as 'C:\Users\sami.laham\Documents\Sam\Data Analysis Training\Luke Barousse\CSV files\df_Spain_pivot.csv'
