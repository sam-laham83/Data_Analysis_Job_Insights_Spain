# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# %%
# Loading Data
dataset = load_dataset('csv', data_files=r'C:\Users\sami.laham\Documents\Sam\Data Analysis Training\Luke Barousse\CSV files\data_jobs.csv')
df = dataset ['train'].to_pandas()

# Data Cleaning

df ['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['job_title_short', 'job_title', 'job_location', 'job_via', 'job_schedule_type', 'job_work_from_home', 'search_location', 'job_posted_date', 'job_no_degree_mention', 'job_health_insurance', 'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg', 'company_name', 'job_skills', 'job_type_skills'],
#         num_rows: 785741
#     })
# })

# %%
df.sample(5)
# Out:
#                   job_title_short  \
# 619182             Data Scientist
# 246358      Senior Data Scientist
# 603115  Machine Learning Engineer
# 18438               Data Engineer
# 129508       Senior Data Engineer
#
#                                                 job_title  \
# 619182                      Data Scientist / okr. Teplice
# 246358  AIML - Senior Data Scientist - Siri and Inform...
# 603115                   Senior Machine Learning Engineer
# 18438                           Data Engineer Airflow H/F
# 129508  Data Engineer, Senior. Job in Stuttgart My Val...
#
#                    job_location                   job_via  \
# 619182                  Czechia         via Cz.indeed.com
# 246358          Santa Clara, CA           via Trabajo.org
# 603115  Cape Town, South Africa              via LinkedIn
# 18438                  Anywhere                via Indeed
# 129508       Stuttgart, Germany  via My Valley Jobs Today
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=785741, step=1, name='Job Index')

# %%
df.index.name = 'Job Index'

# %%
df.head()
# Out:
#                 job_title_short  \
# Job Index
# 0          Senior Data Engineer
# 1                  Data Analyst
# 2                 Data Engineer
# 3                 Data Engineer
# 4                 Data Engineer
#
#                                                    job_title  \
# Job Index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
#
#                            job_location             job_via job_schedule_type  \
# Job Index
# 0                         Watertown, CT     via Work Nearby         Full-time
# 1          Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2                       Berlin, Germany        via LinkedIn         Full-time
# ...

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df_spain = df[df['job_country']== 'Spain']
df_spain.head()
# Out:
#                 job_title_short                 job_title      job_location  \
# Job Index
# 115              Data Scientist   Azure Big Data Engineer     Madrid, Spain
# 124              Data Scientist            DATA SCIENTIST     Madrid, Spain
# 226               Data Engineer  Data Engineer con Python             Spain
# 258               Data Engineer             Data Engineer  Barcelona, Spain
# 264        Senior Data Engineer       Senior Engineer- MS     Madrid, Spain
#
#                 job_via job_schedule_type  job_work_from_home search_location  \
# Job Index
# 115           via BeBee         Full-time               False           Spain
# 124        via LinkedIn         Full-time               False           Spain
# 226        via LinkedIn         Full-time               False           Spain
# 258           via BeBee         Full-time               False           Spain
# 264           via BeBee         Full-time               False           Spain
#
# ...

# %%
df_spain.info
# Out:
# <bound method DataFrame.info of                  job_title_short  \
# Job Index
# 115               Data Scientist
# 124               Data Scientist
# 226                Data Engineer
# 258                Data Engineer
# 264         Senior Data Engineer
# ...                          ...
# 785279              Data Analyst
# 785284         Software Engineer
# 785320     Senior Data Scientist
# 785336             Data Engineer
# 785620             Data Engineer
#
#                                                    job_title  \
# Job Index
# 115                                  Azure Big Data Engineer
# 124                                           DATA SCIENTIST
# 226                                 Data Engineer con Python
# 258                                            Data Engineer
# 264                                      Senior Engineer- MS
# ...                                                      ...
# 785279                                Data - Product Analyst
# ...

# %%
df_spain.reset_index(inplace=True)

# %%
df_spain.set_index ('Job Index', inplace=True)

# %%
df_spain
# Out:
#                  job_title_short  \
# Job Index
# 115               Data Scientist
# 124               Data Scientist
# 226                Data Engineer
# 258                Data Engineer
# 264         Senior Data Engineer
# ...                          ...
# 785279              Data Analyst
# 785284         Software Engineer
# 785320     Senior Data Scientist
# 785336             Data Engineer
# 785620             Data Engineer
#
#                                                    job_title  \
# Job Index
# 115                                  Azure Big Data Engineer
# 124                                           DATA SCIENTIST
# 226                                 Data Engineer con Python
# 258                                            Data Engineer
# 264                                      Senior Engineer- MS
# ...                                                      ...
# 785279                                Data - Product Analyst
# ...

# %%
median_pivot = df_spain.pivot_table (values ='salary_year_avg', index = 'job_title_short', aggfunc = ['median', 'min', 'max'])
median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  86400.0         63000.0        185000.0
# Cloud Engineer                    89100.0         56700.0        125253.0
# Data Analyst                      91977.0         51014.0        155000.0
# Data Engineer                    133000.0         56500.0        165000.0
# Data Scientist                    88128.0         56700.0        165000.0
# Machine Learning Engineer        101029.0         43200.0        225000.0
# Senior Data Analyst              111175.0         89100.0        111175.0
# Senior Data Engineer             147500.0         72900.0        176500.0
# Senior Data Scientist            157500.0         45000.0        211475.0
# Software Engineer                 77050.0         56700.0        205000.0

# %%
median_pivot.sort_values (by=('median', 'salary_year_avg'), ascending = True)
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Software Engineer                 77050.0         56700.0        205000.0
# Business Analyst                  86400.0         63000.0        185000.0
# Data Scientist                    88128.0         56700.0        165000.0
# Cloud Engineer                    89100.0         56700.0        125253.0
# Data Analyst                      91977.0         51014.0        155000.0
# Machine Learning Engineer        101029.0         43200.0        225000.0
# Senior Data Analyst              111175.0         89100.0        111175.0
# Data Engineer                    133000.0         56500.0        165000.0
# Senior Data Engineer             147500.0         72900.0        176500.0
# Senior Data Scientist            157500.0         45000.0        211475.0

# %%
median_pivot.sort_index()
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  86400.0         63000.0        185000.0
# Cloud Engineer                    89100.0         56700.0        125253.0
# Data Analyst                      91977.0         51014.0        155000.0
# Data Engineer                    133000.0         56500.0        165000.0
# Data Scientist                    88128.0         56700.0        165000.0
# Machine Learning Engineer        101029.0         43200.0        225000.0
# Senior Data Analyst              111175.0         89100.0        111175.0
# Senior Data Engineer             147500.0         72900.0        176500.0
# Senior Data Scientist            157500.0         45000.0        211475.0
# Software Engineer                 77050.0         56700.0        205000.0

# %%
median_pivot.sort_index(inplace=False)
median_pivot
# Out:
#                                    median             min             max
#                           salary_year_avg salary_year_avg salary_year_avg
# job_title_short
# Business Analyst                  86400.0         63000.0        185000.0
# Cloud Engineer                    89100.0         56700.0        125253.0
# Data Analyst                      91977.0         51014.0        155000.0
# Data Engineer                    133000.0         56500.0        165000.0
# Data Scientist                    88128.0         56700.0        165000.0
# Machine Learning Engineer        101029.0         43200.0        225000.0
# Senior Data Analyst              111175.0         89100.0        111175.0
# Senior Data Engineer             147500.0         72900.0        176500.0
# Senior Data Scientist            157500.0         45000.0        211475.0
# Software Engineer                 77050.0         56700.0        205000.0
