# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_jobs = pd.read_csv(r'C:\\Users\\sami.laham\\Documents\\Sam\\Data Analysis Training\\Luke Barousse\\CSV files\\df_jobs.csv', encoding='latin1')

# Print the DataFrame to see the first few rows
print(df_jobs.head())
# Out:
#                                    job_title            company_name  \
# 0                   Cloud SysSecOps Engineer     Denodo Technologies
# 1                   Cloud DevSecOps Engineer     Denodo Technologies
# 2  Senior Software Engineer (Data Analytics)                  Aetion
# 3                             Data Scientist  albelli-Photobox Group
# 4                    Data Analyst Coches.net                Adevinta
#
#        job_location
# 0   A Coruña, Spain
# 1   A Coruña, Spain
# 2  Barcelona, Spain
# 3  Barcelona, Spain
# 4  Barcelona, Spain

# %%
df_companies = pd.read_csv(r'C:\Users\sami.laham\Documents\Sam\Data Analysis Training\Luke Barousse\CSV files\df_companies.csv', encoding='ISO-8859-1')

print(df_companies.head())
# Out:
#             company_name                 Industry  \
# 0     Havas Media España                  Clothes
# 1               Deloitte                   Audits
# 2  Aperitivos Snack S.A.                     Food
# 3        Atida | Mifarma  Digital Health Providor
# 4          Atida Mifarma  Digital Health Providor
#
#                                            job_title
# 0  Trainee Digital Analyst At Havas Media Group M...
# 1                                   Consultant, Data
# 2                                       Data Analyst
# 3                                       Data Analyst
# 4                                       Data Analyst

# %%
# Use the correct encoding
df_companies = pd.read_csv(r'C:\Users\sami.laham\Documents\Sam\Data Analysis Training\Luke Barousse\CSV files\df_companies.csv', encoding='latin1')

# Print the first few rows of the DataFrame
print(df_companies.head())
# Out:
#             company_name                 Industry  \
# 0     Havas Media España                  Clothes
# 1               Deloitte                   Audits
# 2  Aperitivos Snack S.A.                     Food
# 3        Atida | Mifarma  Digital Health Providor
# 4          Atida Mifarma  Digital Health Providor
#
#                                            job_title
# 0  Trainee Digital Analyst At Havas Media Group M...
# 1                                   Consultant, Data
# 2                                       Data Analyst
# 3                                       Data Analyst
# 4                                       Data Analyst

# %%
merged_df = df_jobs.merge(df_companies, on='company_name')
merged_df
# Out:
#                                   job_title_x company_name   job_location  \
# 0  Core Data Specialist for The Olympic Games     Deloitte  Madrid, Spain
#
#   Industry       job_title_y
# 0   Audits  Consultant, Data

# %%
merged_df
# Out:
#                                   job_title_x company_name   job_location  \
# 0  Core Data Specialist for The Olympic Games     Deloitte  Madrid, Spain
#
#   Industry       job_title_y
# 0   Audits  Consultant, Data

# %%
# Loading Data
df_Spain_pivot = pd.read_csv (r'C:\Users\sami.laham\Documents\Sam\Data Analysis Training\Luke Barousse\CSV files\df_Spain_pivot.csv', index_col = 'job_posted_month')

# %%
df_Spain_pivot
# Out:
#                   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        187              65           560
# February                       127              31           399
# March                           74              23           363
# April                           45              24           361
# May                             49              11           395
# June                            77              26           344
# July                            74              22           382
# August                         129              47           541
# September                      127              61           403
# October                        211              76           458
# November                       184              88           440
# December                       221              93           531
#
#                   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_Spain_software_pivot = pd.read_csv('C:\\Users\\sami.laham\\Documents\\Sam\\Data Analysis Training\\Luke Barousse\\CSV files\\software_jobs.csv', index_col = 'job_posted_month')
df_Spain_software_pivot
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# ...

# %%
df_Spain_merged = df_Spain_pivot.merge(df_Spain_software_pivot, on = "job_posted_month")

# %%
top_5 = df_Spain_merged
.sum()
.sort_values(ascending=False)
.head()
.index
.to_list()

top_5
# Out:
# ['Front-End Developer',
#  'Back-End Developer',
#  'Full-Stack Developer',
#  'UI/UX Designer',
#  'Data Engineer']

# %%
df_Spain_merged[top_5].plot(kind = 'line')
plt.title ('Monthly Job Postings for Top Tech Jobs in Spain')
plt.xlabel ('2023')
plt.ylabel ('Job Count')
plt.ylim(0, 25000)
plt.legend()
plt.show()
