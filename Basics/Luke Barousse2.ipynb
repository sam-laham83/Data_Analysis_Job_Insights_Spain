# %%
import pandas as pd

DataSet=pd.read_csv('data_jobs.csv', low_memory=False)
DataSet
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
DataSet.head(10)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 7         Data Engineer                                      Data Engineer
# 8      Business Analyst           Technology & Operations Business Analyst
# 9        Data Scientist                                  Data Scientist II
#
#                    job_location             job_via         job_schedule_type  \
# ...

# %%
DataSet.tail(20)
# Out:
#               job_title_short  \
# 785721       Business Analyst
# 785722       Business Analyst
# 785723          Data Engineer
# 785724          Data Engineer
# 785725         Data Scientist
# 785726          Data Engineer
# 785727          Data Engineer
# 785728  Senior Data Scientist
# 785729          Data Engineer
# 785730          Data Engineer
# 785731          Data Engineer
# 785732          Data Engineer
# 785733      Software Engineer
# 785734       Business Analyst
# 785735   Senior Data Engineer
# 785736      Software Engineer
# 785737           Data Analyst
# 785738       Business Analyst
# 785739          Data Engineer
# 785740      Software Engineer
#
#                                                 job_title  \
# 785721                           IT Business Analyst Data
# 785722         Business Analytics Training and Internship
# 785723                                      Data Engineer
# 785724                 Junior Consultant Data Engineering
# ...

# %%
DataSet['job_title_short'].head(10)
# Out:
# 0    Senior Data Engineer
# 1            Data Analyst
# 2           Data Engineer
# 3           Data Engineer
# 4           Data Engineer
# 5           Data Engineer
# 6    Senior Data Engineer
# 7           Data Engineer
# 8        Business Analyst
# 9          Data Scientist
# Name: job_title_short, dtype: object

# %%
DataSet[['job_title_short']]
# Out:
#              job_title_short
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
# [785741 rows x 1 columns]

# %%
DataSet[['job_title_short', 'job_location', 'job_skills']]
# Out:
#              job_title_short                         job_location  \
# 0       Senior Data Engineer                        Watertown, CT
# 1               Data Analyst         Guadalajara, Jalisco, Mexico
# 2              Data Engineer                      Berlin, Germany
# 3              Data Engineer                      San Antonio, TX
# 4              Data Engineer                       Washington, DC
# ...                      ...                                  ...
# 785736     Software Engineer                            Singapura
# 785737          Data Analyst                   Bad Rodach, Jerman
# 785738      Business Analyst                             Malaysia
# 785739         Data Engineer  Newark, New Jersey, Amerika Serikat
# 785740     Software Engineer                                India
#
#                                                job_skills
# 0                                                     NaN
# ...

# %%
DataSet.iloc[90:100]
# Out:
#          job_title_short                                          job_title  \
# 90        Data Scientist                                     Data Scientist
# 91        Data Scientist                                     Data Scientist
# 92         Data Engineer            Remote - Data Engineer - Permanent - W2
# 93          Data Analyst       IT Finance / TBM Data Analyst - Remote | WFH
# 94         Data Engineer                   Data Engineer - Cloud Operations
# 95         Data Engineer                                      Data Engineer
# 96         Data Engineer                                      Data Engineer
# 97          Data Analyst  Systems & Data Analyst - Exploitation, Missing...
# 98  Senior Data Engineer                         Senior Data Engineer (AWS)
# 99         Data Engineer  Senior/Staff Data Engineer – Apache Spark (Jav...
#
#                   job_location                         job_via  \
# 90                   Australia             via BeBee Australia
# ...

# %%
DataSet[['job_title_short', 'job_location', 'job_skills']].iloc[90:100, 0:2]
# Out:
#          job_title_short                job_location
# 90        Data Scientist                   Australia
# 91        Data Scientist               Temuco, Chile
# 92         Data Engineer                    Anywhere
# 93          Data Analyst                    Anywhere
# 94         Data Engineer                    Lehi, UT
# 95         Data Engineer  Mumbai, Maharashtra, India
# 96         Data Engineer                Torrance, CA
# 97          Data Analyst              United Kingdom
# 98  Senior Data Engineer         Toronto, ON, Canada
# 99         Data Engineer                   Miami, FL

# %%
DataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
DataSet.shape
# Out:
# (785741, 17)

# %%
DataSet.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
DataSet.job_title_short.unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
DataSet[DataSet.job_title_short == 'Data Analyst']
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
DataSet[(DataSet.job_title_short == 'Data Analyst') & (DataSet.salary_year_avg >100000)]
# Out:
#        job_title_short                                      job_title  \
# 410       Data Analyst    IT Business Lead Data Analyst - VP - Hybrid
# 1555      Data Analyst                  Data Analyst/Engineer (M/F/D)
# 1681      Data Analyst                                   Data Analyst
# 1684      Data Analyst                       Data Analyst - Data17829
# 1867      Data Analyst  Data Integration Analyst (West Coast/Chicago)
# ...                ...                                            ...
# 783588    Data Analyst                         Data Analytics Manager
# 783866    Data Analyst                Lead Credit Bureau Data Analyst
# 784033    Data Analyst                       Recruitment Data Analyst
# 785187    Data Analyst                                   Data Analyst
# 785515    Data Analyst                                   Data Analyst
#
#                        job_location               job_via job_schedule_type  \
# ...

# %%
DataSet[(DataSet.job_title_short == 'Data Analyst') & (DataSet.job_country =='Germany') & (DataSet.salary_year_avg.notna())]
# Out:
#        job_title_short                                          job_title  \
# 20066     Data Analyst                      Data Analyst Logistik (w/m/d)
# 51100     Data Analyst               (Senior) People Data Analyst (m/w/x)
# 51476     Data Analyst                             Head of Data Analytics
# 56790     Data Analyst  Data Analyst / Data Scientist eBike Systems (w...
# 57582     Data Analyst         Application Consultant in Data Integration
# 58368     Data Analyst                                       Data Manager
# 89707     Data Analyst  Manager Data Strategy - German speaking (all g...
# 110336    Data Analyst                             Data Operation Analyst
# 127888    Data Analyst                                       Data Analyst
# 137735    Data Analyst                               Data Manager (m/w/d)
# 161026    Data Analyst  Research Engineer for Security and Privacy  (f...
# 181422    Data Analyst  Senior Product and Service Owner "Big Data - K...
# ...

# %%
DataSet[(DataSet.job_title_short == 'Data Analyst') & (DataSet.job_location == 'Madrid, Spain') & (DataSet.job_country =='Spain') & (DataSet.salary_year_avg.notna())]
# Out:
#        job_title_short                                         job_title  \
# 17710     Data Analyst                               Master Data Analyst
# 48830     Data Analyst     Consultant (German Speaking) - Data Analytics
# 98496     Data Analyst                      Consultor AWS Data Analytics
# 140557    Data Analyst             Consultant - Process & Data Analytics
# 470176    Data Analyst                                      Data Analyst
# 528085    Data Analyst                         Data Analytics Consultant
# 582681    Data Analyst                                      Data Analyst
# 632227    Data Analyst                               Master Data Analyst
# 713308    Data Analyst  Omnichannel Customer Engagement & Data Analytics
# 781103    Data Analyst                 Junior Data Analyst / After Sales
#
#          job_location          job_via job_schedule_type  job_work_from_home  \
# 17710   Madrid, Spain  via Ai-Jobs.net         Full-time               False
# ...

# %%
DataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
type(DataSet.job_posted_date[0])
# Out:
# str

# %%
DataSet['job_posted_date'] = pd.to_datetime(DataSet.job_posted_date)

# %%
DataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
DataSet.job_posted_date.dt.month
# Out:
# 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_date, Length: 785741, dtype: int32

# %%
DataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
DataSet['job_posted_month'] = DataSet.job_posted_date.dt.month

# %%
DataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
DataSet.sort_values('job_posted_date')
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# 351830                                      Data engineer
# ...

# %%
DataSet.sort_values(by = 'job_posted_date', inplace = True)
DataSet
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# 351830                                      Data engineer
# ...

# %%
DataSet.drop(labels='salary_hour_avg', axis=1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 DataSet.drop(labels='salary_hour_avg', axis=1, inplace = True)
#
# File ~\.conda\envs\notebook\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
DataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785741 entries, 108804 to 90102
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785723 non-null  object
# ...

# %%
DataSet
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# 351830                                      Data engineer
# ...

# %%
DataSet.dropna(subset=['salary_year_avg'], inplace = True)

# %%
DataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 108883 to 327439
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
# ...

# %%
import pandas as pd

DataSet=pd.read_csv('data_jobs.csv', low_memory=False)
#Data Cleaning
DataSet['job_posted_date'] = pd.to_datetime(DataSet['job_posted_date'])
DataSet
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
DataSet.describe()
# Out:
#                      job_posted_date  salary_year_avg  salary_hour_avg
# count                         785741     22003.000000     10662.000000
# mean   2023-06-25 16:02:11.860248576    123286.274072        47.016598
# min              2023-01-01 00:00:04     15000.000000         8.000000
# 25%              2023-03-20 10:05:48     90000.000000        27.500000
# 50%              2023-06-29 06:11:38    115000.000000        45.980000
# 75%              2023-09-27 01:01:16    150000.000000        61.159996
# max              2023-12-31 23:59:58    960000.000000       391.000000
# std                              NaN     48312.449482        21.890738

# %%
DataSet['salary_year_avg'].max()
# Out:
# 960000.0

# %%
DataSet.describe()
# Out:
#                      job_posted_date  salary_year_avg  salary_hour_avg
# count                         785741     22003.000000     10662.000000
# mean   2023-06-25 16:02:11.860248576    123286.274072        47.016598
# min              2023-01-01 00:00:04     15000.000000         8.000000
# 25%              2023-03-20 10:05:48     90000.000000        27.500000
# 50%              2023-06-29 06:11:38    115000.000000        45.980000
# 75%              2023-09-27 01:01:16    150000.000000        61.159996
# max              2023-12-31 23:59:58    960000.000000       391.000000
# std                              NaN     48312.449482        21.890738

# %%
DataSet['salary_year_avg'].min()
# Out:
# 15000.0

# %%
min_salary = DataSet['salary_year_avg'].idxmin()

# %%
DataSet.iloc[min_salary]
# Out:
# job_title_short                                              Data Engineer
# job_title                                           Data Engineer - Hadoop
# job_location                                                        Brazil
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Brazil
# job_posted_date                                        2023-12-09 10:05:30
# job_no_degree_mention                                                 True
# job_health_insurance                                                 False
# job_country                                                         Brazil
# salary_rate                                                           year
# ...

# %%
DataSet['job_title_short'].unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
DataSet['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
 DataSet.groupby('job_title_short')['salary_year_avg'].min()
# Out:
# job_title_short
# Business Analyst             16500.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                15000.0
# Data Scientist               27000.0
# Machine Learning Engineer    30000.0
# Senior Data Analyst          30000.0
# Senior Data Engineer         35000.0
# Senior Data Scientist        45000.0
# Software Engineer            28000.0
# Name: salary_year_avg, dtype: float64

# %%
 DataSet.groupby('job_title_short')['salary_year_avg'].median()
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64

# %%
 DataSet.groupby(['job_title_short', 'job_country'])['salary_year_avg'].median()
# Out:
# job_title_short    job_country
# Business Analyst   Afghanistan        NaN
#                    Albania            NaN
#                    Algeria            NaN
#                    Angola             NaN
#                    Argentina      71100.0
#                                    ...
# Software Engineer  Venezuela          NaN
#                    Vietnam        53600.0
#                    Yemen              NaN
#                    Zambia             NaN
#                    Zimbabwe           NaN
# Name: salary_year_avg, Length: 1387, dtype: float64

# %%
DataSet.groupby(['job_title_short', 'job_country'])['salary_year_avg'].agg(('min', 'max', 'median'))
DataSet.dropna(subset=['salary_year_avg'], inplace = True)

# %%
DataSet.groupby(['job_title_short', 'job_country'])['salary_year_avg'].agg(('min', 'max', 'median'))
# Out:
#                                             min       max    median
# job_title_short   job_country
# Business Analyst  Argentina             63000.0   79200.0   71100.0
#                   Australia             63000.0  130000.0   70000.0
#                   Bangladesh            16500.0   16500.0   16500.0
#                   Belgium               72900.0   89100.0   89100.0
#                   Bulgaria              63000.0   89100.0   71925.0
# ...                                         ...       ...       ...
# Software Engineer Ukraine               54000.0   54000.0   54000.0
#                   United Arab Emirates  79200.0   79200.0   79200.0
#                   United Kingdom        89100.0  160000.0   89100.0
#                   United States         48982.0  375000.0  130000.0
#                   Vietnam               28000.0   79200.0   53600.0
#
# [598 rows x 3 columns]

# %%
DataSet['job_country'].value_counts()
# Out:
# job_country
# United States             15766
# Sudan                      1623
# India                       582
# Canada                      463
# United Kingdom              287
#                           ...
# Montenegro                    1
# Jamaica                       1
# Mali                          1
# Azerbaijan                    1
# Bosnia and Herzegovina        1
# Name: count, Length: 108, dtype: int64

# %%
DataSet['job_country'].value_counts().head(20)
# Out:
# job_country
# United States     15766
# Sudan              1623
# India               582
# Canada              463
# United Kingdom      287
# Germany             257
# France              237
# Poland              200
# Spain               144
# Portugal            131
# Mexico              111
# Israel              103
# Singapore            98
# South Africa         92
# Netherlands          87
# Greece               82
# Australia            74
# Colombia             69
# Philippines          68
# South Korea          63
# Name: count, dtype: int64

# %%
Spain_Jobs = DataSet[DataSet['job_country'] == "Spain"]
Spain_Jobs
# Out:
#              job_title_short                                   job_title  \
# 4521       Software Engineer                  Power BI Solution Engineer
# 7170    Senior Data Engineer   Senior Software Engineer (Data Analytics)
# 12335         Data Scientist              DESARROLLADOR PYTHON - PYSPARK
# 13913      Software Engineer  Staff Quality Assurance Engineer (ETL/SQL)
# 17710           Data Analyst                         Master Data Analyst
# ...                      ...                                         ...
# 777078        Data Scientist         (Senior) Digital Analytics Engineer
# 781103          Data Analyst           Junior Data Analyst / After Sales
# 781830         Data Engineer                        Azure Data Architect
# 782773          Data Analyst                   Data Analyst - Operations
# 783528        Cloud Engineer              Elasticsearch + AWS Consultant
#
#             job_location          job_via job_schedule_type  \
# ...

# %%
Spain_Jobs = Spain_Jobs[Spain_Jobs['salary_year_avg'].notna()]
Spain_Jobs
# Out:
#              job_title_short                                   job_title  \
# 4521       Software Engineer                  Power BI Solution Engineer
# 7170    Senior Data Engineer   Senior Software Engineer (Data Analytics)
# 12335         Data Scientist              DESARROLLADOR PYTHON - PYSPARK
# 13913      Software Engineer  Staff Quality Assurance Engineer (ETL/SQL)
# 17710           Data Analyst                         Master Data Analyst
# ...                      ...                                         ...
# 777078        Data Scientist         (Senior) Digital Analytics Engineer
# 781103          Data Analyst           Junior Data Analyst / After Sales
# 781830         Data Engineer                        Azure Data Architect
# 782773          Data Analyst                   Data Analyst - Operations
# 783528        Cloud Engineer              Elasticsearch + AWS Consultant
#
#             job_location          job_via job_schedule_type  \
# ...

# %%
Spain_Jobs.groupby(['job_title_short','job_location'])['salary_year_avg'].agg(['median', 'min', 'max', 'count']).sort_values(by='median')
# Out:
#                                               median       min       max  \
# job_title_short           job_location
# Machine Learning Engineer Getafe, Spain      43200.0   43200.0   43200.0
# Senior Data Scientist     Anywhere           45000.0   45000.0   45000.0
# Data Engineer             Anywhere           56500.0   56500.0   56500.0
# Software Engineer         Madrid, Spain      56700.0   56700.0   89100.0
# Business Analyst          Madrid, Spain      63000.0   63000.0  185000.0
# Software Engineer         Barcelona, Spain   65000.0   65000.0   65000.0
# Data Scientist            Gijón, Spain       69962.5   69962.5   69962.5
#                           Valencia, Spain    72900.0   72900.0   72900.0
#                           Spain              80850.0   57600.0  165000.0
#                           Seville, Spain     88128.0   88128.0   88128.0
# Data Engineer             Málaga, Spain      88811.5   56700.0  147500.0
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [1, 2, 3, 4]
y = [1, 2, 3, 4]

plt.plot(x, y)
plt.show()

# %%
Spain_Jobs.job_posted_date.head()
# Out:
# 4521    2023-05-09 13:39:12
# 7170    2023-07-24 13:27:58
# 12335   2023-03-30 13:32:57
# 13913   2023-01-30 13:24:10
# 17710   2023-02-03 13:44:52
# Name: job_posted_date, dtype: datetime64[ns]

# %%
plt.plot(Spain_Jobs.job_posted_date, Spain_Jobs.job_posted_date)
plt.show()

# %%
date_counts = Spain_Jobs.job_posted_date.value_counts()
date_counts = date_counts.sort_index()

# %%
date_counts
# Out:
# job_posted_date
# 2023-01-11 18:25:48    1
# 2023-01-12 03:25:37    1
# 2023-01-12 08:45:57    1
# 2023-01-12 11:45:59    1
# 2023-01-12 21:45:53    1
#                       ..
# 2023-12-16 09:17:57    1
# 2023-12-17 18:21:36    1
# 2023-12-27 22:12:13    1
# 2023-12-30 12:08:41    1
# 2023-12-30 23:08:41    1
# Name: count, Length: 143, dtype: int64

# %%
plt.plot(date_counts.index, date_counts)
plt.show()

# %%
Spain_Jobs['job_posted_month'] = Spain_Jobs['job_posted_date'].dt.month
Spain_Jobs
# Out:
#              job_title_short                                   job_title  \
# 4521       Software Engineer                  Power BI Solution Engineer
# 7170    Senior Data Engineer   Senior Software Engineer (Data Analytics)
# 12335         Data Scientist              DESARROLLADOR PYTHON - PYSPARK
# 13913      Software Engineer  Staff Quality Assurance Engineer (ETL/SQL)
# 17710           Data Analyst                         Master Data Analyst
# ...                      ...                                         ...
# 777078        Data Scientist         (Senior) Digital Analytics Engineer
# 781103          Data Analyst           Junior Data Analyst / After Sales
# 781830         Data Engineer                        Azure Data Architect
# 782773          Data Analyst                   Data Analyst - Operations
# 783528        Cloud Engineer              Elasticsearch + AWS Consultant
#
#             job_location          job_via job_schedule_type  \
# ...

# %%
Spain_Jobs = Spain_Jobs.drop('job_posted_month', axis=1)

# %%
type(Spain_Jobs)
# Out:
# pandas.core.frame.DataFrame

# %%
monthly_counts = Spain_Jobs.Job_Posted_Month.value_counts()

monthly_counts = monthly_counts.sort_index()
monthly_counts
# Out:
# Job_Posted_Month
# 1     14
# 2     17
# 3     16
# 4     22
# 5     16
# 6     11
# 7     16
# 8      7
# 9      2
# 11     6
# 12    17
# Name: count, dtype: int64

# %%
plt.plot(monthly_counts.index, monthly_counts.values)
plt.show()

# %%
Spain_Jobs.job_title_short
# Out:
# 4521         Software Engineer
# 7170      Senior Data Engineer
# 12335           Data Scientist
# 13913        Software Engineer
# 17710             Data Analyst
#                   ...
# 777078          Data Scientist
# 781103            Data Analyst
# 781830           Data Engineer
# 782773            Data Analyst
# 783528          Cloud Engineer
# Name: job_title_short, Length: 144, dtype: object

# %%
job_counts = Spain_Jobs.job_title_short.value_counts()

# %%
plt.barh(job_counts.index, job_counts)
# Out:
# <BarContainer object of 10 artists>

# %%
job_counts = job_counts.sort_values(ascending = True)
plt.barh(job_counts.index, job_counts)
plt.ylabel('Postings by Job Title')
plt.yticks(rotation=45, ha='right')
plt.title('Count of Job Postings')
plt.show()

# %%
job_counts.plot (kind='bar')
plt.ylabel('Count of Job Postings')
plt.xlabel ('')
plt.xticks(rotation=45, ha='right')
plt.title('Job Postings per Job Title')
plt.savefig("job_counts.jpg")
plt.show()

# %%
 Spain_Jobs[['job_posted_date', 'salary_year_avg']].dropna(subset = ['salary_year_avg'])
# Out:
#            job_posted_date  salary_year_avg
# 4521   2023-05-09 13:39:12          56700.0
# 7170   2023-07-24 13:27:58          89100.0
# 12335  2023-03-30 13:32:57          89100.0
# 13913  2023-01-30 13:24:10          89100.0
# 17710  2023-02-03 13:44:52          51014.0
# ...                    ...              ...
# 777078 2023-04-25 05:17:30         147500.0
# 781103 2023-04-06 06:16:47          98500.0
# 781830 2023-01-21 07:11:50         165000.0
# 782773 2023-03-24 06:31:59          98500.0
# 783528 2023-03-26 06:27:50          89100.0
#
# [144 rows x 2 columns]

# %%
Spain_Jobs.plot(x = 'job_posted_date', y = 'salary_year_avg', kind = 'line')
plt.ylabel('Count of Job Postings')
plt.xlabel ('')
plt.xticks(rotation=45, ha='right')
plt.title('Job Postings per Job Title')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
Spain_Jobs.groupby('job_title_short')['salary_year_avg'].median().sort_values()
# Out:
# job_title_short
# Software Engineer             77050.0
# Business Analyst              86400.0
# Data Scientist                88128.0
# Cloud Engineer                89100.0
# Data Analyst                  91977.0
# Machine Learning Engineer    101029.0
# Senior Data Analyst          111175.0
# Data Engineer                133000.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        157500.0
# Name: salary_year_avg, dtype: float64

# %%
Spain_Job_Salary = Spain_Jobs.groupby('job_title_short')['salary_year_avg'].mean().sort_values()

# %%
from matplotlib.ticker import FuncFormatter

# Define the formatter function for Euros
def to_k(x, pos):
    """Convert number to string with 'K' as thousands in Euros."""
    return f'€{int(x / 1000)}K'

# Create formatter using FuncFormatter
formatter = FuncFormatter(to_k)

# Create histogram
plt.figure(figsize=(10, 5))
plt.hist(Spain_Jobs['salary_year_avg'], bins=30, edgecolor='black')

# Set title and labels
plt.title('Distribution of Average Yearly Salaries')
plt.xlabel('Average Yearly Salary (Euros)')
plt.ylabel('Number of Jobs')

# Apply the formatter to the x-axis
plt.gca().xaxis.set_major_formatter(formatter)
plt.show()

# %%
Spain_Job_Salary.plot (kind='barh')
plt.xlabel ('Salary (€EUR)')
plt.ylabel ('')
plt.title('Medium Salary by Job Title')
plt.show()

# %%
import urllib.request
import ssl


def urllib_get_2018():
    # Using a protected member like this is not any more fragile
    # than extending the class and using it. I would use it.
    url = 'https://localhost:6667/my-endpoint'
    ssl._create_default_https_context = ssl._create_unverified_context
    with urllib.request.urlopen(url = url) as f:
        print(f.read().decode('utf-8'))


def urllib_get_2022():
    # Finally! Able to use the publice API. Happy happy!
    url = 'https://localhost:6667/my-endpoint'
    scontext = ssl.SSLContext(ssl.PROTOCOL_TLS)
    scontext.verify_mode = ssl.VerifyMode.CERT_NONE
    with urllib.request.urlopen(url = url, context=scontext) as f:
        print(f.read().decode('utf-8'))
